# %%
from pymongo import MongoClient
import json
import geopandas as gdp
from cartoframes.viz import Map, Layer, popup_element
import folium
import requests
import time
import sys
from folium import plugins
from folium import IFrame
from folium.features import DivIcon
from geopy.distance import geodesic

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
token = os.getenv("token")

# %%
json_file_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\data\company_data.json"

with open(json_file_path, 'r') as json_file:
    company_data = json.load(json_file)

# %% [markdown]
# ### This is the company in San Francisco, which I'm interested to buy.

# %%
map_center = [37.790998, -122.394668]
companies_map = folium.Map(location=map_center, zoom_start=15)

for company in company_data:
    name = company['name']
    latitude = company['latitude']
    longitude = company['longitude']
    popup_text = f"{name}<br>Lat: {latitude}<br>Lon: {longitude}"

    icon_color = {
        'Company1': 'lightblue',
        'Company2': 'lightgreen',
        'Company3': 'orange',
        'Company4': 'yellow',
    }.get(name, 'mediumorchid')

    custom_icon_html = f'<div style="background-color: {icon_color}; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;">{name}</div>'

    folium.Marker(
        location=[latitude, longitude],
        popup=popup_text,
        icon=folium.DivIcon(html=custom_icon_html)
    ).add_to(companies_map)

folder_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\geomaps"
file_name = 'companies_map.html'
full_path = os.path.join(folder_path, file_name)

companies_map.save(full_path)
companies_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13c4866393a5c59f6a07c7f95f7b6950 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13c4866393a5c59f6a07c7f95f7b6950&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13c4866393a5c59f6a07c7f95f7b6950 = L.map(
#                 &quot;map_13c4866393a5c59f6a07c7f95f7b6950&quot;,
#                 {
#                     center: [37.790998, -122.394668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8b72383379c21786d78ee5073e6d82ca = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_13c4866393a5c59f6a07c7f95f7b6950);
#
#
#             var marker_8b9447e07ca2c9dea72a8d210892230b = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_13c4866393a5c59f6a07c7f95f7b6950);
#
#
#             var div_icon_365f48329ae869072fc18df1cd21f972 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_8b9447e07ca2c9dea72a8d210892230b.setIcon(div_icon_365f48329ae869072fc18df1cd21f972);
#
#
#         var popup_09d1bd959ff3a165b659b3ca9cb1f851 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_356c8db990a443deb7574d0e1968bad2 = $(`&lt;div id=&quot;html_356c8db990a443deb7574d0e1968bad2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_09d1bd959ff3a165b659b3ca9cb1f851.setContent(html_356c8db990a443deb7574d0e1968bad2);
#
#
#
#         marker_8b9447e07ca2c9dea72a8d210892230b.bindPopup(popup_09d1bd959ff3a165b659b3ca9cb1f851)
#         ;
#
#
#
#
#             var marker_b06013fec29431b994160bd9b7c56c00 = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_13c4866393a5c59f6a07c7f95f7b6950);
#
#
#             var div_icon_c33a09e47e7e3b82d14ec8b5093f554b = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_b06013fec29431b994160bd9b7c56c00.setIcon(div_icon_c33a09e47e7e3b82d14ec8b5093f554b);
#
#
#         var popup_2278d7ce55e8f407b00d3799a00302be = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_387778e9324718c91495969c24a8f039 = $(`&lt;div id=&quot;html_387778e9324718c91495969c24a8f039&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_2278d7ce55e8f407b00d3799a00302be.setContent(html_387778e9324718c91495969c24a8f039);
#
#
#
#         marker_b06013fec29431b994160bd9b7c56c00.bindPopup(popup_2278d7ce55e8f407b00d3799a00302be)
#         ;
#
#
#
#
#             var marker_4ba9031e43d1977a970c7e11f9d8784c = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_13c4866393a5c59f6a07c7f95f7b6950);
#
#
#             var div_icon_ae88c275632c51a5dbe70012af2eb2ae = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_4ba9031e43d1977a970c7e11f9d8784c.setIcon(div_icon_ae88c275632c51a5dbe70012af2eb2ae);
#
#
#         var popup_4ed941d1983de71857d67dc70f64514a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_633b4ce57fb415e034b621ccaf684ffe = $(`&lt;div id=&quot;html_633b4ce57fb415e034b621ccaf684ffe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_4ed941d1983de71857d67dc70f64514a.setContent(html_633b4ce57fb415e034b621ccaf684ffe);
#
#
#
#         marker_4ba9031e43d1977a970c7e11f9d8784c.bindPopup(popup_4ed941d1983de71857d67dc70f64514a)
#         ;
#
#
#
#
#             var marker_941f951c838d0ca11f9339fc21df6b55 = L.marker(
#                 [37.392936, -122.07948],
#                 {}
#             ).addTo(map_13c4866393a5c59f6a07c7f95f7b6950);

# %%
map_center = [37.790998, -122.394668]
companies_map2 = folium.Map(location=map_center, zoom_start=15)

for company in company_data:
    name = company['name']
    latitude = company['latitude']
    longitude = company['longitude']
    popup_text = f"{name}<br>Lat: {latitude}<br>Lon: {longitude}"

    icon_color = {
        'Company1': 'lightblue',
        'Company2': 'lightgreen',
        'Company3': 'orange',
        'Company4': 'yellow',
    }.get(name, 'mediumorchid')

    custom_icon_html = f'<div style="background-color: {icon_color}; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;">{name}</div>'

    folium.Marker(
        location=[latitude, longitude],
        popup=popup_text,
        icon=folium.DivIcon(html=custom_icon_html)
    ).add_to(companies_map2)

folder_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\geomaps"
file_name = 'companies_map2.html'
full_path = os.path.join(folder_path, file_name)

companies_map2.save(full_path)
companies_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_367a56195c69d5cc38e46ec53fe120f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_367a56195c69d5cc38e46ec53fe120f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_367a56195c69d5cc38e46ec53fe120f1 = L.map(
#                 &quot;map_367a56195c69d5cc38e46ec53fe120f1&quot;,
#                 {
#                     center: [37.790998, -122.394668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_553e5d948bda83031f2fd1b85ae31dbf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var marker_364cd138f4bfd8260f28518e1a5ffa2c = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var div_icon_bf901bddedbde069df1b9ef8dc867760 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_364cd138f4bfd8260f28518e1a5ffa2c.setIcon(div_icon_bf901bddedbde069df1b9ef8dc867760);
#
#
#         var popup_357b004f03c7e4b5a188871f1a596211 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04b0398980f0d93a04ee4a5a5a01e358 = $(`&lt;div id=&quot;html_04b0398980f0d93a04ee4a5a5a01e358&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_357b004f03c7e4b5a188871f1a596211.setContent(html_04b0398980f0d93a04ee4a5a5a01e358);
#
#
#
#         marker_364cd138f4bfd8260f28518e1a5ffa2c.bindPopup(popup_357b004f03c7e4b5a188871f1a596211)
#         ;
#
#
#
#
#             var marker_e135c04f38b764acd2cc5bf356c65d03 = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var div_icon_76a2294b42d47b4e75cd088a9b4064ab = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_e135c04f38b764acd2cc5bf356c65d03.setIcon(div_icon_76a2294b42d47b4e75cd088a9b4064ab);
#
#
#         var popup_c1cafc8fe761e5920db7c35d230d242c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8019fe8263514685c7b3c57f8e332472 = $(`&lt;div id=&quot;html_8019fe8263514685c7b3c57f8e332472&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_c1cafc8fe761e5920db7c35d230d242c.setContent(html_8019fe8263514685c7b3c57f8e332472);
#
#
#
#         marker_e135c04f38b764acd2cc5bf356c65d03.bindPopup(popup_c1cafc8fe761e5920db7c35d230d242c)
#         ;
#
#
#
#
#             var marker_81d9b97290f3e1e7fbacd9b75ad85be2 = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var div_icon_700688b1aa764e3fe4211b98c5e1fe0a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_81d9b97290f3e1e7fbacd9b75ad85be2.setIcon(div_icon_700688b1aa764e3fe4211b98c5e1fe0a);
#
#
#         var popup_66a5d64cebc79895afd70469c63db8b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8efc8fb09eaeaafb49dfe490c2bb9f48 = $(`&lt;div id=&quot;html_8efc8fb09eaeaafb49dfe490c2bb9f48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_66a5d64cebc79895afd70469c63db8b8.setContent(html_8efc8fb09eaeaafb49dfe490c2bb9f48);
#
#
#
#         marker_81d9b97290f3e1e7fbacd9b75ad85be2.bindPopup(popup_66a5d64cebc79895afd70469c63db8b8)
#         ;
#
#
#
#
#             var marker_02eeddbd9a3445a28bbe9681fdc53604 = L.marker(
#                 [37.392936, -122.07948],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);

# %% [markdown]
# ### General function to call to check places

# %%
lat=37.790998
lon=-122.394668

def foursquare_places(query, token, lat=37.790998, lon=-122.394668, limit=5, radius=None):
    endpoint = f'https://api.foursquare.com/v3/places/search?query={query}&ll={lat},{lon}&limit={limit}'

    if radius is not None:
        endpoint += f'&radius={radius}'  # Agregar el parámetro de radio si se proporciona

    headers = {
        "accept": "application/json",
        "Authorization": token
    }

    try:
        response = requests.get(endpoint, headers=headers)
        response.raise_for_status()
        data = response.json()
        venues = data.get('results', [])
        results = []
        for venue in venues:
            name = venue.get('name')
            location = venue.get('geocodes', {}).get('main', {})
            lat = location.get('latitude')
            lng = location.get('longitude')
            results.append({
                'name': name,
                'lat': lat,
                'lng': lng
            })
        return results
    except requests.exceptions.RequestException as e:
        print(f"Error: {e}")
        return []
    finally:
        time.sleep(1)

# %% [markdown]
# ### Check for bars around the area

# %%
query = "bar"
bar = foursquare_places("bar", token, lat=lat, lon=lon, limit=50, radius=2000)

map_bar = folium.Map(location=[lat, lon], zoom_start=14)

for location in bar:
    name = location['name']
    lat = location['lat']
    lng = location['lng']
    
    folium.Marker([lat, lng], popup=name).add_to(map_bar)
    
    icon = folium.Icon(icon="beer", prefix="fa", color="orange", icon_color="white")
    folium.Marker(
        location=[lat, lng],
        icon=icon
    ).add_to(companies_map2)

    
folder_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\geomaps"
file_name = 'companies_map2.html'
full_path = os.path.join(folder_path, file_name)
companies_map2.save(full_path)
companies_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_367a56195c69d5cc38e46ec53fe120f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_367a56195c69d5cc38e46ec53fe120f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_367a56195c69d5cc38e46ec53fe120f1 = L.map(
#                 &quot;map_367a56195c69d5cc38e46ec53fe120f1&quot;,
#                 {
#                     center: [37.790998, -122.394668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_553e5d948bda83031f2fd1b85ae31dbf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var marker_364cd138f4bfd8260f28518e1a5ffa2c = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var div_icon_bf901bddedbde069df1b9ef8dc867760 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_364cd138f4bfd8260f28518e1a5ffa2c.setIcon(div_icon_bf901bddedbde069df1b9ef8dc867760);
#
#
#         var popup_357b004f03c7e4b5a188871f1a596211 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04b0398980f0d93a04ee4a5a5a01e358 = $(`&lt;div id=&quot;html_04b0398980f0d93a04ee4a5a5a01e358&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_357b004f03c7e4b5a188871f1a596211.setContent(html_04b0398980f0d93a04ee4a5a5a01e358);
#
#
#
#         marker_364cd138f4bfd8260f28518e1a5ffa2c.bindPopup(popup_357b004f03c7e4b5a188871f1a596211)
#         ;
#
#
#
#
#             var marker_e135c04f38b764acd2cc5bf356c65d03 = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var div_icon_76a2294b42d47b4e75cd088a9b4064ab = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_e135c04f38b764acd2cc5bf356c65d03.setIcon(div_icon_76a2294b42d47b4e75cd088a9b4064ab);
#
#
#         var popup_c1cafc8fe761e5920db7c35d230d242c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8019fe8263514685c7b3c57f8e332472 = $(`&lt;div id=&quot;html_8019fe8263514685c7b3c57f8e332472&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_c1cafc8fe761e5920db7c35d230d242c.setContent(html_8019fe8263514685c7b3c57f8e332472);
#
#
#
#         marker_e135c04f38b764acd2cc5bf356c65d03.bindPopup(popup_c1cafc8fe761e5920db7c35d230d242c)
#         ;
#
#
#
#
#             var marker_81d9b97290f3e1e7fbacd9b75ad85be2 = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var div_icon_700688b1aa764e3fe4211b98c5e1fe0a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_81d9b97290f3e1e7fbacd9b75ad85be2.setIcon(div_icon_700688b1aa764e3fe4211b98c5e1fe0a);
#
#
#         var popup_66a5d64cebc79895afd70469c63db8b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8efc8fb09eaeaafb49dfe490c2bb9f48 = $(`&lt;div id=&quot;html_8efc8fb09eaeaafb49dfe490c2bb9f48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_66a5d64cebc79895afd70469c63db8b8.setContent(html_8efc8fb09eaeaafb49dfe490c2bb9f48);
#
#
#
#         marker_81d9b97290f3e1e7fbacd9b75ad85be2.bindPopup(popup_66a5d64cebc79895afd70469c63db8b8)
#         ;
#
#
#
#
#             var marker_02eeddbd9a3445a28bbe9681fdc53604 = L.marker(
#                 [37.392936, -122.07948],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);

# %% [markdown]
# ### Checking starbucks

# %%
starbucks = foursquare_places("starbucks", token, lat=lat, lon=lon, limit=50, radius=1000)

map_starbucks = folium.Map(location=[lat, lon], zoom_start=14)

for location in starbucks:
    name = location['name']
    lat = location['lat']
    lng = location['lng']
    
    folium.Marker([lat, lng], popup=name).add_to(map_starbucks)
    
    icon = folium.Icon(icon="coffee", prefix="fa", color="darkgreen", icon_color="white")
    folium.Marker(
        location=[lat, lng],
        icon=icon
    ).add_to(companies_map2)

    
folder_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\geomaps"
file_name = 'companies_map2.html'
full_path = os.path.join(folder_path, file_name)
companies_map2.save(full_path)
companies_map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_367a56195c69d5cc38e46ec53fe120f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_367a56195c69d5cc38e46ec53fe120f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_367a56195c69d5cc38e46ec53fe120f1 = L.map(
#                 &quot;map_367a56195c69d5cc38e46ec53fe120f1&quot;,
#                 {
#                     center: [37.790998, -122.394668],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_553e5d948bda83031f2fd1b85ae31dbf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var marker_364cd138f4bfd8260f28518e1a5ffa2c = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var div_icon_bf901bddedbde069df1b9ef8dc867760 = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_364cd138f4bfd8260f28518e1a5ffa2c.setIcon(div_icon_bf901bddedbde069df1b9ef8dc867760);
#
#
#         var popup_357b004f03c7e4b5a188871f1a596211 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_04b0398980f0d93a04ee4a5a5a01e358 = $(`&lt;div id=&quot;html_04b0398980f0d93a04ee4a5a5a01e358&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_357b004f03c7e4b5a188871f1a596211.setContent(html_04b0398980f0d93a04ee4a5a5a01e358);
#
#
#
#         marker_364cd138f4bfd8260f28518e1a5ffa2c.bindPopup(popup_357b004f03c7e4b5a188871f1a596211)
#         ;
#
#
#
#
#             var marker_e135c04f38b764acd2cc5bf356c65d03 = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var div_icon_76a2294b42d47b4e75cd088a9b4064ab = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_e135c04f38b764acd2cc5bf356c65d03.setIcon(div_icon_76a2294b42d47b4e75cd088a9b4064ab);
#
#
#         var popup_c1cafc8fe761e5920db7c35d230d242c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8019fe8263514685c7b3c57f8e332472 = $(`&lt;div id=&quot;html_8019fe8263514685c7b3c57f8e332472&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_c1cafc8fe761e5920db7c35d230d242c.setContent(html_8019fe8263514685c7b3c57f8e332472);
#
#
#
#         marker_e135c04f38b764acd2cc5bf356c65d03.bindPopup(popup_c1cafc8fe761e5920db7c35d230d242c)
#         ;
#
#
#
#
#             var marker_81d9b97290f3e1e7fbacd9b75ad85be2 = L.marker(
#                 [37.788482, -122.409173],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);
#
#
#             var div_icon_700688b1aa764e3fe4211b98c5e1fe0a = L.divIcon({&quot;className&quot;: &quot;empty&quot;, &quot;html&quot;: &quot;\u003cdiv style=\&quot;background-color: mediumorchid; border-radius: 50%; width: 30px; height: 30px; display: flex; justify-content: center; align-items: center;\&quot;\u003eKyte\u003c/div\u003e&quot;});
#             marker_81d9b97290f3e1e7fbacd9b75ad85be2.setIcon(div_icon_700688b1aa764e3fe4211b98c5e1fe0a);
#
#
#         var popup_66a5d64cebc79895afd70469c63db8b8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8efc8fb09eaeaafb49dfe490c2bb9f48 = $(`&lt;div id=&quot;html_8efc8fb09eaeaafb49dfe490c2bb9f48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kyte&lt;br&gt;Lat: 37.788482&lt;br&gt;Lon: -122.409173&lt;/div&gt;`)[0];
#                 popup_66a5d64cebc79895afd70469c63db8b8.setContent(html_8efc8fb09eaeaafb49dfe490c2bb9f48);
#
#
#
#         marker_81d9b97290f3e1e7fbacd9b75ad85be2.bindPopup(popup_66a5d64cebc79895afd70469c63db8b8)
#         ;
#
#
#
#
#             var marker_02eeddbd9a3445a28bbe9681fdc53604 = L.marker(
#                 [37.392936, -122.07948],
#                 {}
#             ).addTo(map_367a56195c69d5cc38e46ec53fe120f1);

# %% [markdown]
# ### Checking for schools

# %%
school = foursquare_places("elementary school", token, lat=lat, lon=lon, limit=50, radius=8000)

map_school = folium.Map(location=[lat, lon], zoom_start=13, limit=50)

for location in school:
    name = location['name']
    lat = location['lat']
    lng = location['lng']
    
    folium.Marker([lat, lng], popup=name).add_to(map_school)
    
    icon = folium.Icon(icon="graduation-cap", prefix="fa", color="blue", icon_color="white")
    folium.Marker(
        location=[lat, lng],
        icon=icon
    ).add_to(companies_map2)

    
folder_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\geomaps"
file_name = 'companies_map2.html'
full_path = os.path.join(folder_path, file_name)
companies_map2.save(full_path)
companies_map2

# %%
vegan = foursquare_places("vegan", token, lat=lat, lon=lon, limit=50, radius=8000)

map_vegan = folium.Map(location=[lat, lon], zoom_start=14)

for location in vegan:
    name = location['name']
    lat = location['lat']
    lng = location['lng']
    
    
    folium.Marker([lat, lng], popup=name).add_to(map_vegan)
    
    icon = folium.Icon(icon="leaf", prefix="fa", color="green", icon_color="white")
    folium.Marker(
        location=[lat, lng],
        icon=icon
    ).add_to(companies_map2)

    
folder_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\geomaps"
file_name = 'companies_map2.html'
full_path = os.path.join(folder_path, file_name)
companies_map2.save(full_path)
companies_map2

# %% [markdown]
# ### Checking for pet groomers

# %%
pet = foursquare_places("pet-groommer", token, lat=lat, lon=lon, limit=50, radius=8000)   
map_pet = folium.Map(location=[lat, lon], zoom_start=13, limit=10)

for location in pet:
    name = location['name']
    lat = location['lat']
    lng = location['lng']
    
    folium.Marker([lat, lng], popup=name).add_to(map_pet)
    
    icon = folium.Icon(icon="paw", prefix="fa", color="pink", icon_color="white")
    folium.Marker(
        location=[lat, lng],
        icon=icon
    ).add_to(companies_map2)

    
folder_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\geomaps"
file_name = 'companies_map2.html'
full_path = os.path.join(folder_path, file_name)
map_pet.save(full_path)
companies_map2.save(full_path)
companies_map2

# %% [markdown]
# ### Checking for transport options

# %%
metro = foursquare_places("metro", token, lat=lat, lon=lon, limit=50, radius=8000)   
map_transport = folium.Map(location=[lat, lon], zoom_start=13, limit=10)

for location in metro:
    name = location['name']
    lat = location['lat']
    lng = location['lng']
    
    folium.Marker([lat, lng], popup=name).add_to(map_transport)
    
    icon = folium.Icon(icon="train", prefix="fa", color="black", icon_color="white")
    folium.Marker(
        location=[lat, lng],
        icon=icon
    ).add_to(companies_map2)

    
folder_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\geomaps"
file_name = 'companies_map2.html'
full_path = os.path.join(folder_path, file_name)
companies_map2.save(full_path)
companies_map2.save(full_path)
companies_map2

# %% [markdown]
# ### Checking for basketball court

# %%
basketball = foursquare_places("basketball court", token, lat=lat, lon=lon, limit=20, radius=9000)   
map_basketball = folium.Map(location=[lat, lon], zoom_start=15, limit=10)

for location in basketball:
    name = location['name']
    lat = location['lat']
    lng = location['lng']
    
    folium.Marker([lat, lng], popup=name).add_to(map_basketball)
    
    icon = folium.Icon(icon="wrench", prefix="fa", color="red", icon_color="white")
    folium.Marker(
        location=[lat, lng],
        icon=icon
    ).add_to(companies_map2)

    
folder_path = r"C:\Users\photo\Desktop\Ironhack\projects\project-III-geolocation\geomaps"
file_name = 'companies_map2.html'
full_path = os.path.join(folder_path, file_name)
companies_map2.save(full_path)
companies_map2
